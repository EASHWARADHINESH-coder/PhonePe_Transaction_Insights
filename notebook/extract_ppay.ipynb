# %%
# IMPORT LIBRARIES

import pandas as pd
import json
import os

# %%
# LOAD THE DATA AND EXTRACTION FOR AGGREGATED TRANSACTION DATAS

path=r"D:\PHONEPAY_PROJECT\first_project\pulse\data\aggregated\transaction\country\india\state\\"
path = path.replace("\\", "/")
agg_state_trans_list=sorted(os.listdir(path))
print(agg_state_trans_list)

clm1={'state':[], 'year':[],'quarter':[],'transaction_type':[], 'transaction_count':[], 'transaction_amount':[]}

for i in agg_state_trans_list:
    p_i=path+i+"/"
    agg_yr=os.listdir(p_i)
    for j in agg_yr:
        p_j=p_i+j+"/"
        agg_yr_list=os.listdir(p_j)
        for k in agg_yr_list:
            p_k=p_j+k
            with open(p_k, 'r') as Data:
                D = json.load(Data)
                for z in D['data']['transactionData']:
                    name=z['name']
                    count=z['paymentInstruments'][0]['count']
                    amount=z['paymentInstruments'][0]['amount']
                    clm1['transaction_type'].append(name)
                    clm1['transaction_count'].append(count)
                    clm1['transaction_amount'].append(amount)
                    clm1['state'].append(i)
                    clm1['year'].append(j)
                    clm1['quarter'].append(int(k.replace('.json', '')))

agg_trans=pd.DataFrame(clm1)
print(agg_trans)
# Out:
# ['andaman-&-nicobar-islands', 'andhra-pradesh', 'arunachal-pradesh', 'assam', 'bihar', 'chandigarh', 'chhattisgarh', 'dadra-&-nagar-haveli-&-daman-&-diu', 'delhi', 'goa', 'gujarat', 'haryana', 'himachal-pradesh', 'jammu-&-kashmir', 'jharkhand', 'karnataka', 'kerala', 'ladakh', 'lakshadweep', 'madhya-pradesh', 'maharashtra', 'manipur', 'meghalaya', 'mizoram', 'nagaland', 'odisha', 'puducherry', 'punjab', 'rajasthan', 'sikkim', 'tamil-nadu', 'telangana', 'tripura', 'uttar-pradesh', 'uttarakhand', 'west-bengal']
#                           state  year  quarter          transaction_type  \
# 0     andaman-&-nicobar-islands  2018        1  Recharge & bill payments
# 1     andaman-&-nicobar-islands  2018        1     Peer-to-peer payments
# 2     andaman-&-nicobar-islands  2018        1         Merchant payments
# 3     andaman-&-nicobar-islands  2018        1        Financial Services
# 4     andaman-&-nicobar-islands  2018        1                    Others
# ...

# %%
# LOAD THE DATA AND EXTRACTION FOR AGGREGATED INSURANCE DATAS

path=r"D:\PHONEPAY_PROJECT\first_project\pulse\data\aggregated\insurance\country\india\state\\"
path = path.replace("\\", "/")
agg_state_ins_list=os.listdir(path)
print(agg_state_ins_list)

clm2 = {'state':[], 'year':[],'quarter':[],'insurance_type':[], 'insurance_count':[], 'insurance_amount':[]}

for i in agg_state_ins_list:
  p_i = path + i + "/"
  agg_yr = os.listdir(p_i)
  for j in agg_yr:
    p_j = p_i + j + "/"
    agg_yr_list = os.listdir(p_j)
    for k in agg_yr_list:
      p_k = p_j + k
      with open(p_k, 'r') as Data:
          D = json.load(Data)
          for z in D['data']['transactionData']:
              name = z['name']
              count=z['paymentInstruments'][0]['count']
              amount=z['paymentInstruments'][0]['amount']
              clm2['insurance_type'].append(name)
              clm2['insurance_count'].append(count)
              clm2['insurance_amount'].append(amount)
              clm2['state'].append(i)
              clm2['year'].append(j)
              clm2['quarter'].append(int(k.strip('.json')))


agg_ins=pd.DataFrame(clm2)
print(agg_ins)
# Out:
# ['andaman-&-nicobar-islands', 'andhra-pradesh', 'arunachal-pradesh', 'assam', 'bihar', 'chandigarh', 'chhattisgarh', 'dadra-&-nagar-haveli-&-daman-&-diu', 'delhi', 'goa', 'gujarat', 'haryana', 'himachal-pradesh', 'jammu-&-kashmir', 'jharkhand', 'karnataka', 'kerala', 'ladakh', 'lakshadweep', 'madhya-pradesh', 'maharashtra', 'manipur', 'meghalaya', 'mizoram', 'nagaland', 'odisha', 'puducherry', 'punjab', 'rajasthan', 'sikkim', 'tamil-nadu', 'telangana', 'tripura', 'uttar-pradesh', 'uttarakhand', 'west-bengal']
#                          state  year  quarter insurance_type  insurance_count  \
# 0    andaman-&-nicobar-islands  2020        2      Insurance                6
# 1    andaman-&-nicobar-islands  2020        3      Insurance               41
# 2    andaman-&-nicobar-islands  2020        4      Insurance              124
# 3    andaman-&-nicobar-islands  2021        1      Insurance              225
# 4    andaman-&-nicobar-islands  2021        2      Insurance              137
# ...

# %%
# LOAD THE DATA AND EXTRACTION FOR AGGREGATED USER DATAS

path=r"D:\PHONEPAY_PROJECT\first_project\pulse\data\aggregated\user\country\india\state\\"
path = path.replace("\\", "/")
agg_state_user_list=sorted(os.listdir(path))
agg_state_user_list

clm3 = {
    'state':[],
    'year':[],
    'quarter':[],
    'brand':[],
    'brand_users':[],
    'percentage':[],
    'registeredUsers':[],
    'appOpens':[]
}

for i in agg_state_user_list:
    p_i = path + i + "/"
    agg_yr = os.listdir(p_i)
    for j in agg_yr:
        p_j = p_i + j + "/"
        agg_yr_list = os.listdir(p_j)
        for k in agg_yr_list:
            p_k = p_j + k
            with open(p_k, 'r') as Data:
                D = json.load(Data)
                registered_users = D["data"]["aggregated"]["registeredUsers"]
                app_opens = D["data"]["aggregated"]["appOpens"]
                if "usersByDevice" in D["data"] and D["data"]["usersByDevice"]:
                    for z in D["data"]["usersByDevice"]:
                        clm3['state'].append(i)
                        clm3['year'].append(int(j))
                        clm3['quarter'].append(int(k.replace('.json','')))
                        clm3['brand'].append(z['brand'])
                        clm3['brand_users'].append(z['count'])
                        clm3['percentage'].append(z['percentage'])
                        clm3['registeredUsers'].append(registered_users)
                        clm3['appOpens'].append(app_opens)

agg_users = pd.DataFrame(clm3)
print(agg_users)
# Out:
#                           state  year  quarter    brand  brand_users  \
# 0     andaman-&-nicobar-islands  2018        1   Xiaomi         1665
# 1     andaman-&-nicobar-islands  2018        1  Samsung         1445
# 2     andaman-&-nicobar-islands  2018        1     Vivo          982
# 3     andaman-&-nicobar-islands  2018        1     Oppo          501
# 4     andaman-&-nicobar-islands  2018        1  OnePlus          332
# ...                         ...   ...      ...      ...          ...
# 6727                west-bengal  2022        1   Lenovo       330017
# 6728                west-bengal  2022        1  Infinix       284678
# 6729                west-bengal  2022        1     Asus       280347
# 6730                west-bengal  2022        1    Apple       277752
# 6731                west-bengal  2022        1   Others      2196334
#
#       percentage  registeredUsers   appOpens
# 0       0.247033             6740          0
# 1       0.214392             6740          0
# ...

# %%
# LOAD THE DATA AND EXTRACTION FOR MAP TRANSACTION DATAS

path=r"D:\PHONEPAY_PROJECT\first_project\pulse\data\map\transaction\hover\country\india\state\\"
path = path.replace("\\", "/")
map_state_trans_list=sorted(os.listdir(path))
print(map_state_trans_list)

clm4={'state':[], 'year':[],'quarter':[],'type':[], 'count':[], 'amount':[]}

for i in map_state_trans_list:
    p_i=path+i+"/"
    map_yr=os.listdir(p_i)
    for j in map_yr:
        p_j=p_i+j+"/"
        map_yr_list=os.listdir(p_j)
        for k in map_yr_list:
            p_k=p_j+k
            with open(p_k, 'r') as Data:
                D = json.load(Data)
                for z in D['data']['hoverDataList']:
                    name=z['name']
                    type=z['metric'][0]['type']
                    count=z['metric'][0]['count']
                    amount=z['metric'][0]['amount']
                    clm4['type'].append(z['name'])
                    clm4['count'].append(count)
                    clm4['amount'].append(amount)
                    clm4['state'].append(i)
                    clm4['year'].append(j)
                    clm4['quarter'].append(int(k.replace('.json', '')))
              

map_trans=pd.DataFrame(clm4)
print(map_trans)
# Out:
# ['andaman-&-nicobar-islands', 'andhra-pradesh', 'arunachal-pradesh', 'assam', 'bihar', 'chandigarh', 'chhattisgarh', 'dadra-&-nagar-haveli-&-daman-&-diu', 'delhi', 'goa', 'gujarat', 'haryana', 'himachal-pradesh', 'jammu-&-kashmir', 'jharkhand', 'karnataka', 'kerala', 'ladakh', 'lakshadweep', 'madhya-pradesh', 'maharashtra', 'manipur', 'meghalaya', 'mizoram', 'nagaland', 'odisha', 'puducherry', 'punjab', 'rajasthan', 'sikkim', 'tamil-nadu', 'telangana', 'tripura', 'uttar-pradesh', 'uttarakhand', 'west-bengal']
#                            state  year  quarter  \
# 0      andaman-&-nicobar-islands  2018        1
# 1      andaman-&-nicobar-islands  2018        1
# 2      andaman-&-nicobar-islands  2018        1
# 3      andaman-&-nicobar-islands  2018        2
# 4      andaman-&-nicobar-islands  2018        2
# ...                          ...   ...      ...
# 20599                west-bengal  2024        4
# 20600                west-bengal  2024        4
# ...

# %%
# LOAD THE DATA AND EXTRACTION FOR MAP INSURANCE DATAS

path=r"D:\PHONEPAY_PROJECT\first_project\pulse\data\map\insurance\hover\country\india\state\\"
path = path.replace("\\", "/")
map_state_ins_list=sorted(os.listdir(path))
print(map_state_ins_list)

clm5={'state':[], 'year':[],'quarter':[],'type':[], 'count':[], 'amount':[]}

for i in map_state_ins_list:
    p_i=path+i+"/"
    map_yr=os.listdir(p_i)
    for j in map_yr:
        p_j=p_i+j+"/"
        map_yr_list=os.listdir(p_j)
        for k in map_yr_list:
            p_k=p_j+k
            with open(p_k, 'r') as Data:
                D = json.load(Data)
                for z in D['data']['hoverDataList']:
                    name=z['name']
                    type=z['metric'][0]['type'] 
                    count=z['metric'][0]['count']
                    amount=z['metric'][0]['amount']
                    clm5['type'].append(z['name'])
                    clm5['count'].append(count)
                    clm5['amount'].append(amount)
                    clm5['state'].append(i)
                    clm5['year'].append(j)
                    clm5['quarter'].append(int(k.replace('.json', '')))

map_ins=pd.DataFrame(clm5)
print(map_ins)
# Out:
# ['andaman-&-nicobar-islands', 'andhra-pradesh', 'arunachal-pradesh', 'assam', 'bihar', 'chandigarh', 'chhattisgarh', 'dadra-&-nagar-haveli-&-daman-&-diu', 'delhi', 'goa', 'gujarat', 'haryana', 'himachal-pradesh', 'jammu-&-kashmir', 'jharkhand', 'karnataka', 'kerala', 'ladakh', 'lakshadweep', 'madhya-pradesh', 'maharashtra', 'manipur', 'meghalaya', 'mizoram', 'nagaland', 'odisha', 'puducherry', 'punjab', 'rajasthan', 'sikkim', 'tamil-nadu', 'telangana', 'tripura', 'uttar-pradesh', 'uttarakhand', 'west-bengal']
#                            state  year  quarter  \
# 0      andaman-&-nicobar-islands  2020        2
# 1      andaman-&-nicobar-islands  2020        2
# 2      andaman-&-nicobar-islands  2020        3
# 3      andaman-&-nicobar-islands  2020        3
# 4      andaman-&-nicobar-islands  2020        3
# ...                          ...   ...      ...
# 13871                west-bengal  2024        4
# 13872                west-bengal  2024        4
# ...

# %%
# LOAD THE DATA AND EXTRACTION FOR MAP USER DATAS

path=r"D:\PHONEPAY_PROJECT\first_project\pulse\data\map\user\hover\country\india\state\\"
path = path.replace("\\", "/")
map_state_user_list=sorted(os.listdir(path))
print(map_state_user_list)

clm6 = {'state':[], 'year':[],'quarter':[],'registeredUsers':[],'appOpens':[]}

for i in map_state_user_list:
  p_i = path + i + "/"
  agg_yr = os.listdir(p_i)
  for j in agg_yr:
    p_j = p_i + j + "/"
    agg_yr_list = os.listdir(p_j)
    for k in agg_yr_list:
      p_k = p_j + k
      with open(p_k, 'r') as Data:
          D = json.load(Data)
          if "hoverData" in D["data"] and D["data"]["hoverData"]:
              for district, values in D["data"]["hoverData"].items():
                  clm6['state'].append(i)
                  clm6['year'].append(j)
                  clm6['quarter'].append(int(k.replace('.json', '')))
                  clm6['registeredUsers'].append(values.get("registeredUsers", 0))
                  clm6['appOpens'].append(values.get("appOpens", 0))


map_users=pd.DataFrame(clm6)
print(map_users)
# Out:
# ['andaman-&-nicobar-islands', 'andhra-pradesh', 'arunachal-pradesh', 'assam', 'bihar', 'chandigarh', 'chhattisgarh', 'dadra-&-nagar-haveli-&-daman-&-diu', 'delhi', 'goa', 'gujarat', 'haryana', 'himachal-pradesh', 'jammu-&-kashmir', 'jharkhand', 'karnataka', 'kerala', 'ladakh', 'lakshadweep', 'madhya-pradesh', 'maharashtra', 'manipur', 'meghalaya', 'mizoram', 'nagaland', 'odisha', 'puducherry', 'punjab', 'rajasthan', 'sikkim', 'tamil-nadu', 'telangana', 'tripura', 'uttar-pradesh', 'uttarakhand', 'west-bengal']
#                            state  year  quarter  registeredUsers   appOpens
# 0      andaman-&-nicobar-islands  2018        1              632          0
# 1      andaman-&-nicobar-islands  2018        1             5846          0
# 2      andaman-&-nicobar-islands  2018        1              262          0
# 3      andaman-&-nicobar-islands  2018        2              911          0
# 4      andaman-&-nicobar-islands  2018        2             8143          0
# ...

# %%
# LOAD THE DATA AND EXTRACTION FOR TOP TRANSACTION DATAS

path=r"D:\PHONEPAY_PROJECT\first_project\pulse\data\top\transaction\country\india\state\\"
path = path.replace("\\", "/")
top_state_trans_list=sorted(os.listdir(path))
print(top_state_trans_list)

clm7={'state':[], 'year':[],'quarter':[], 'entityName':[], 'type':[], 'count':[], 'amount':[]}

for i in top_state_trans_list:
    p_i=path+i+"/"
    agg_yr=os.listdir(p_i)
    for j in agg_yr:
        p_j=p_i+j+"/"
        agg_yr_list=os.listdir(p_j)
        for k in agg_yr_list:
            p_k=p_j+k
            with open(p_k, 'r') as Data:
                D = json.load(Data)
            districts = D.get('data', {}).get('districts') or []
            for z in districts:
                entity = z.get('entityName')
                metric = z.get('metric', {})
                clm7['state'].append(i)
                clm7['year'].append(j)
                clm7['quarter'].append(int(k.replace('.json', '')))
                clm7['entityName'].append(entity)
                clm7['type'].append(metric.get('type'))
                clm7['count'].append(metric.get('count'))
                clm7['amount'].append(metric.get('amount'))

top_trans=pd.DataFrame(clm7)
print(top_trans)
# Out:
# ['andaman-&-nicobar-islands', 'andhra-pradesh', 'arunachal-pradesh', 'assam', 'bihar', 'chandigarh', 'chhattisgarh', 'dadra-&-nagar-haveli-&-daman-&-diu', 'delhi', 'goa', 'gujarat', 'haryana', 'himachal-pradesh', 'jammu-&-kashmir', 'jharkhand', 'karnataka', 'kerala', 'ladakh', 'lakshadweep', 'madhya-pradesh', 'maharashtra', 'manipur', 'meghalaya', 'mizoram', 'nagaland', 'odisha', 'puducherry', 'punjab', 'rajasthan', 'sikkim', 'tamil-nadu', 'telangana', 'tripura', 'uttar-pradesh', 'uttarakhand', 'west-bengal']
#                           state  year  quarter                entityName  \
# 0     andaman-&-nicobar-islands  2018        1             south andaman
# 1     andaman-&-nicobar-islands  2018        1                  nicobars
# 2     andaman-&-nicobar-islands  2018        1  north and middle andaman
# 3     andaman-&-nicobar-islands  2018        2             south andaman
# 4     andaman-&-nicobar-islands  2018        2                  nicobars
# ...

# %%
# LOAD THE DATA AND EXTRACTION FOR TOP INSURANCE DATAS

path=r"D:\PHONEPAY_PROJECT\first_project\pulse\data\top\insurance\country\india\state\\"
path = path.replace("\\", "/")
top_state_ins_list=sorted(os.listdir(path))
print(top_state_ins_list)

clm8={'state':[], 'year':[],'quarter':[], 'entityName':[], 'type':[], 'count':[], 'amount':[]}

for i in top_state_ins_list:
    p_i=path+i+"/"
    agg_yr=os.listdir(p_i)
    for j in agg_yr:
        p_j=p_i+j+"/"
        agg_yr_list=os.listdir(p_j)
        for k in agg_yr_list:
            p_k=p_j+k
            with open(p_k, 'r') as Data:
                D = json.load(Data)
            districts = D.get('data', {}).get('districts') or []
            for z in districts:
                entity = z.get('entityName')
                metric = z.get('metric', {})
                clm8['state'].append(i)
                clm8['year'].append(j)
                clm8['quarter'].append(int(k.replace('.json', '')))
                clm8['entityName'].append(entity)
                clm8['type'].append(metric.get('type'))
                clm8['count'].append(metric.get('count'))
                clm8['amount'].append(metric.get('amount'))

top_ins=pd.DataFrame(clm8)
print(top_ins)
# Out:
# ['andaman-&-nicobar-islands', 'andhra-pradesh', 'arunachal-pradesh', 'assam', 'bihar', 'chandigarh', 'chhattisgarh', 'dadra-&-nagar-haveli-&-daman-&-diu', 'delhi', 'goa', 'gujarat', 'haryana', 'himachal-pradesh', 'jammu-&-kashmir', 'jharkhand', 'karnataka', 'kerala', 'ladakh', 'lakshadweep', 'madhya-pradesh', 'maharashtra', 'manipur', 'meghalaya', 'mizoram', 'nagaland', 'odisha', 'puducherry', 'punjab', 'rajasthan', 'sikkim', 'tamil-nadu', 'telangana', 'tripura', 'uttar-pradesh', 'uttarakhand', 'west-bengal']
#                           state  year  quarter                entityName  \
# 0     andaman-&-nicobar-islands  2020        2                  nicobars
# 1     andaman-&-nicobar-islands  2020        2             south andaman
# 2     andaman-&-nicobar-islands  2020        3             south andaman
# 3     andaman-&-nicobar-islands  2020        3                  nicobars
# 4     andaman-&-nicobar-islands  2020        3  north and middle andaman
# ...

# %%
# LOAD THE DATA AND EXTRACTION FOR TOP USER DATAS

path=r"D:\PHONEPAY_PROJECT\first_project\pulse\data\top\user\country\india\state\\"
path = path.replace("\\", "/")
top_state_user_list=sorted(os.listdir(path))
print(top_state_user_list)

clm9={'state':[], 'year':[],'quarter':[], 'entityName':[], 'registeredUsers':[]}

for i in top_state_ins_list:
    p_i=path+i+"/"
    agg_yr=os.listdir(p_i)
    for j in agg_yr:
        p_j=p_i+j+"/"
        agg_yr_list=os.listdir(p_j)
        for k in agg_yr_list:
            p_k=p_j+k
            with open(p_k, 'r') as Data:
                D = json.load(Data)
            districts = D.get('data', {}).get('districts') or []
            for z in districts:
                clm9['state'].append(i)
                clm9['year'].append(j)
                clm9['quarter'].append(int(k.replace('.json', '')))
                clm9['entityName'].append(z.get('name'))
                clm9['registeredUsers'].append(z.get('registeredUsers'))

top_users=pd.DataFrame(clm9)
print(top_users)
# Out:
# ['andaman-&-nicobar-islands', 'andhra-pradesh', 'arunachal-pradesh', 'assam', 'bihar', 'chandigarh', 'chhattisgarh', 'dadra-&-nagar-haveli-&-daman-&-diu', 'delhi', 'goa', 'gujarat', 'haryana', 'himachal-pradesh', 'jammu-&-kashmir', 'jharkhand', 'karnataka', 'kerala', 'ladakh', 'lakshadweep', 'madhya-pradesh', 'maharashtra', 'manipur', 'meghalaya', 'mizoram', 'nagaland', 'odisha', 'puducherry', 'punjab', 'rajasthan', 'sikkim', 'tamil-nadu', 'telangana', 'tripura', 'uttar-pradesh', 'uttarakhand', 'west-bengal']
#                           state  year  quarter                entityName  \
# 0     andaman-&-nicobar-islands  2018        1             south andaman
# 1     andaman-&-nicobar-islands  2018        1  north and middle andaman
# 2     andaman-&-nicobar-islands  2018        1                  nicobars
# 3     andaman-&-nicobar-islands  2018        2             south andaman
# 4     andaman-&-nicobar-islands  2018        2  north and middle andaman
# ...

# %%
# IMPORT LIBRARIES FOR CONNECTING THE SQL

import mysql.connector
import pandas as pd
import os
from sqlalchemy import create_engine, text, MetaData, Table, Column, Integer, String, select, and_

# %%
# SQL INSERTION

username = "root"
password = "your_password"
host = "localhost"
database = "phonepe_db"

engine = create_engine(f"mysql+pymysql://{username}:{password}@{host}/{database}")

# %%
# CLM1 TABLE INSERTION TO SQL

agg_trans.to_sql(
    name="aggregated_transactions",
    con=engine,
    if_exists="replace",   # use 'append' if you don't want to delete existing table
    index=False,
    chunksize=1000,
    method="multi"
)

print("✅ DataFrame successfully written to MySQL!")
# Out:
# ✅ DataFrame successfully written to MySQL!

# %%
# CLM2 TABLE INSERTION TO SQL

agg_ins.to_sql(
    name="aggregated_insurance",
    con=engine,
    if_exists="replace",   # use 'append' if you don't want to delete existing table
    index=False,
    chunksize=1000,
    method="multi"
)

print("✅ DataFrame successfully written to MySQL!")
# Out:
# ✅ DataFrame successfully written to MySQL!

# %%
# CLM3 TABLE INSERTION TO SQL

agg_users.to_sql(
    name="aggregated_users",
    con=engine,
    if_exists="replace",   # use 'append' if you don't want to delete existing table
    index=False,
    chunksize=1000,
    method="multi"
)

print("✅ DataFrame successfully written to MySQL!")
# Out:
# ✅ DataFrame successfully written to MySQL!

# %%
# CLM4 TABLE INSERTION TO SQL

map_trans.to_sql(
    name="map_transactions",
    con=engine,
    if_exists="replace",   # use 'append' if you don't want to delete existing table
    index=False,
    chunksize=1000,
    method="multi"
)

print("✅ DataFrame successfully written to MySQL!")
# Out:
# ✅ DataFrame successfully written to MySQL!

# %%
# CLM5 TABLE INSERTION TO SQL

map_ins.to_sql(
    name="map_insurance",
    con=engine,
    if_exists="replace",   # use 'append' if you don't want to delete existing table
    index=False,
    chunksize=1000,
    method="multi"
)

print("✅ DataFrame successfully written to MySQL!")
# Out:
# ✅ DataFrame successfully written to MySQL!

# %%
# CLM6 TABLE INSERTION TO SQL

map_users.to_sql(
    name="map_users",
    con=engine,
    if_exists="replace",   # use 'append' if you don't want to delete existing table
    index=False,
    chunksize=1000,
    method="multi"
)

print("✅ DataFrame successfully written to MySQL!")
# Out:
# ✅ DataFrame successfully written to MySQL!

# %%
# CLM7 TABLE INSERTION TO SQL

top_trans.to_sql(
    name="top_transactions",
    con=engine,
    if_exists="replace",   # use 'append' if you don't want to delete existing table
    index=False,
    chunksize=1000,
    method="multi"
)

print("✅ DataFrame successfully written to MySQL!")
# Out:
# ✅ DataFrame successfully written to MySQL!

# %%
# CLM8 TABLE INSERTION TO SQL

top_ins.to_sql(
    name="top_insurance",
    con=engine,
    if_exists="replace",   # use 'append' if you don't want to delete existing table
    index=False,
    chunksize=1000,
    method="multi"
)

print("✅ DataFrame successfully written to MySQL!")
# Out:
# ✅ DataFrame successfully written to MySQL!

# %%
# CLM9 TABLE INSERTION TO SQL

top_users.to_sql(
    name="top_users",
    con=engine,
    if_exists="replace",   # use 'append' if you don't want to delete existing table
    index=False,
    chunksize=1000,
    method="multi"
)

print("✅ DataFrame successfully written to MySQL!")
# Out:
# ✅ DataFrame successfully written to MySQL!
